# %% [markdown]
# # Geocoding with Geopy and GeoPandas

# %% [markdown]
# Overview
#
# We will be working with an Excel sheet containing addresses of Hurricane Evacuation Centers in New York City. We will geocode these addresses and display the locations on a map.
#
# Input Layers:
#
# `Hurricane_Evacuation_Centers.xlsx`: A spreadsheet containing names and addresses of hurricane shelters inn NYC.
#
# Output:
#
# `hurricane_evacuation_centers.shp`: A shapefile with geocoded locations of the hurricane evacuation centers
#
# Data Credit: NYC Open Data Portal. [source](https://data.cityofnewyork.us/Public-Safety/Hurricane-Evacuation-Centers-Map-/ayer-cga7)

# %% [markdown]
# ## Setup and Data Download
#
# The following blocks of code will install the required packages and download the datasets to your Colab environment.

# %%
# %%capture
if 'google.colab' in str(get_ipython()):
    # !apt install libspatialindex-dev
    # !pip install fiona shapely pyproj rtree mapclassify
    # !pip install geopandas
    # !pip install openpyxl
    # !pip install leafmap

# %%
import os
import re
import pandas as pd
import geopandas as gpd
import leafmap.foliumap as leafmap
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
data_folder = 'data'
output_folder = 'output'

if not os.path.exists(data_folder):
    os.mkdir(data_folder)
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %%
def download(url):
    filename = os.path.join(data_folder, os.path.basename(url))
    if not os.path.exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)

download('https://github.com/spatialthoughts/python-tutorials/raw/main/data/' +
         'Hurricane_Evacuation_Centers.xlsx')

# %% [markdown]
# ## Procedure

# %% [markdown]
# Read the `Bars_and_pubs__with_patron_capacity.csv` file and convert it to a GeoDataFrame.

# %%
excel_file = 'Hurricane_Evacuation_Centers.xlsx'
excel_file_path = os.path.join(data_folder, excel_file)
address_df = pd.read_excel(excel_file_path, skiprows=[0])
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
# [64 rows x 7 columns]

# %% [markdown]
# The Nominatim geocoder expects the addresses with certain format. We fix our source addresses by making the street numbers as orfinal numbers
#
# Examples
#
# - `45-30 36 Street` → `45-30 36th Street`.
# - `544 7 Avenue` → `544 7th Avenue`

# %%
def make_ordinal(match):
    n = int(match.group(1))
    if 11 <= (n % 100) <= 13:
        suffix = 'th'
    else:
        suffix = ['th', 'st', 'nd', 'rd', 'th'][min(n % 10, 4)]
    return str(n) + suffix + match.group(2)

def update_address(row):
  old_address = row['ADDRESS']
  pattern = r'(\d+)(\s+(?:Street|Avenue|Blvd|Drive))'
  result = re.sub(pattern, make_ordinal, old_address)
  return result

address_df['ADDRESS_FIXED'] = address_df.apply(update_address, axis=1)
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE  \
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
#                            ADDRESS_FIXED
# 0                      147-26 25th Drive
# 1                       141 Macon Street
# 2                         544 7th Avenue
# 3                  2780 Reservoir Avenue
# 4                        7002 4th Avenue
# ..                                   ...
# 59                     730 Bryant Avenue
# 60                    2760 Briggs Avenue
# 61                     45-30 36th Street
# 62                    1827 Archer Street
# 63  1780 Dr. Martin Luther King Jr. Blvd
#
# [64 rows x 8 columns]

# %% [markdown]
# We also create a new column containing the full address. The `CITY` column in the data are actually boroughs of NYC and adding it causing many geocoding requests to fail. Instead, we use the city name 'NYC' for all addresses.

# %%
address_df['Full_Address'] = (
    address_df['ADDRESS_FIXED'] + ',' +
    'NYC' + ',' +
    address_df['STATE']+ ',' +
    address_df['ZIP_CODE'].astype(str))
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE  \
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
#                            ADDRESS_FIXED  \
# 0                      147-26 25th Drive
# 1                       141 Macon Street
# 2                         544 7th Avenue
# 3                  2780 Reservoir Avenue
# 4                        7002 4th Avenue
# ..                                   ...
# 59                     730 Bryant Avenue
# 60                    2760 Briggs Avenue
# 61                     45-30 36th Street
# 62                    1827 Archer Street
# 63  1780 Dr. Martin Luther King Jr. Blvd
#
#                                          Full_Address
# 0                      147-26 25th Drive,NYC,NY,11354
# 1                       141 Macon Street,NYC,NY,11216
# 2                         544 7th Avenue,NYC,NY,11215
# 3                  2780 Reservoir Avenue,NYC,NY,10468
# 4                        7002 4th Avenue,NYC,NY,11209
# ..                                                ...
# 59                     730 Bryant Avenue,NYC,NY,10474
# 60                    2760 Briggs Avenue,NYC,NY,10458
# 61                     45-30 36th Street,NYC,NY,11101
# 62                    1827 Archer Street,NYC,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NYC,NY,10453
#
# [64 rows x 9 columns]

# %%
from tqdm.notebook import tqdm

tqdm.pandas()

locator = Nominatim(user_agent='spatialthoughts', timeout=10)
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

address_df['location'] = address_df['Full_Address'].progress_apply(geocode)
address_df
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]
#                                        EC_Name  \
# 0                          J.H.S. 185 - Queens
# 1                          I.S. 258 - Brooklyn
# 2                           I.S. 88 - Brooklyn
# 3                                Walton HS - X
# 4   P.S./I.S.30 Mary White Ovington - Brooklyn
# ..                                         ...
# 59                            I.S. 201 - Bronx
# 60                             P.S. 46 - Bronx
# 61                             Aviation HS - Q
# 62                            P.S. 102 - Bronx
# 63  Morris Heights Educational Complex - Bronx
#
#                                          Full_Address  \
# 0                      147-26 25th Drive,NYC,NY,11354
# 1                       141 Macon Street,NYC,NY,11216
# 2                         544 7th Avenue,NYC,NY,11215
# 3                  2780 Reservoir Avenue,NYC,NY,10468
# 4                        7002 4th Avenue,NYC,NY,11209
# ..                                                ...
# 59                     730 Bryant Avenue,NYC,NY,10474
# 60                    2760 Briggs Avenue,NYC,NY,10458
# 61                     45-30 36th Street,NYC,NY,11101
# 62                    1827 Archer Street,NYC,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NYC,NY,10453
#
#                                              location
# 0   (147-26, 25th Drive, Linden Hill, Queens, City...
# 1   (Junior High School 258, 141, Macon Street, Be...
# 2   (544, 7th Avenue, South Slope, Sunset Park, Ki...
# 3   (Celia Cruz High School of Music, 2780, Reserv...
# 4   (7002, 4th Avenue, Bay Ridge, Brooklyn, Kings ...
# ..                                                ...
# 59  (730, Bryant Avenue, Hunts Point, Bronx County...
# 60  (2760, Briggs Avenue, Bedford Park, Bronx Coun...
# 61  (45-30, 36th Street, Sunnyside, Queens, City o...
# 62  (Public School 102, 1827, Archer Street, Bronx...
# 63  (East 125th Street, Manhattan Community Board ...
#
# [63 rows x 3 columns]

# %%
address_df['latitude'] = address_df['location'].apply(lambda loc: loc.latitude if loc else None)
address_df['longitude'] = address_df['location'].apply(lambda loc: loc.longitude if loc else None)
address_df
# Out:
#                                        EC_Name  \
# 0                          J.H.S. 185 - Queens
# 1                          I.S. 258 - Brooklyn
# 2                           I.S. 88 - Brooklyn
# 3                                Walton HS - X
# 4   P.S./I.S.30 Mary White Ovington - Brooklyn
# ..                                         ...
# 59                            I.S. 201 - Bronx
# 60                             P.S. 46 - Bronx
# 61                             Aviation HS - Q
# 62                            P.S. 102 - Bronx
# 63  Morris Heights Educational Complex - Bronx
#
#                                          Full_Address  \
# 0                      147-26 25th Drive,NYC,NY,11354
# 1                       141 Macon Street,NYC,NY,11216
# 2                         544 7th Avenue,NYC,NY,11215
# 3                  2780 Reservoir Avenue,NYC,NY,10468
# 4                        7002 4th Avenue,NYC,NY,11209
# ..                                                ...
# 59                     730 Bryant Avenue,NYC,NY,10474
# 60                    2760 Briggs Avenue,NYC,NY,10458
# 61                     45-30 36th Street,NYC,NY,11101
# 62                    1827 Archer Street,NYC,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NYC,NY,10453
#
#                                              location   latitude  longitude
# 0   (147-26, 25th Drive, Linden Hill, Queens, City...  40.774893 -73.818642
# 1   (Junior High School 258, 141, Macon Street, Be...  40.681918 -73.945597
# 2   (544, 7th Avenue, South Slope, Sunset Park, Ki...  40.660181 -73.987931
# 3   (Celia Cruz High School of Music, 2780, Reserv...  40.870595 -73.897498
# 4   (7002, 4th Avenue, Bay Ridge, Brooklyn, Kings ...  40.633625 -74.024038
# ..                                                ...        ...        ...
# 59  (730, Bryant Avenue, Hunts Point, Bronx County...  40.816040 -73.885264
# 60  (2760, Briggs Avenue, Bedford Park, Bronx Coun...  40.867729 -73.890294
# 61  (45-30, 36th Street, Sunnyside, Queens, City o...  40.743475 -73.929464
# 62  (Public School 102, 1827, Archer Street, Bronx...  40.838106 -73.865790
# 63  (East 125th Street, Manhattan Community Board ...  40.802551 -73.933098
#
# [63 rows x 5 columns]

# %%
failed = address_df[address_df['location'].isna()]
failed
# Out:
# Empty DataFrame
# Columns: [EC_Name, Full_Address, location, latitude, longitude]
# Index: []

# %%
address_df = address_df[~address_df['location'].isna()]
address_df = address_df[['EC_Name', 'Full_Address', 'latitude', 'longitude']]
address_df.rename(columns = {'EC_Name': 'Name', 'Full_Address': 'Address'}, inplace=True)

# %%
geometry = gpd.points_from_xy(address_df.longitude, address_df.latitude)
address_gdf = gpd.GeoDataFrame(address_df, crs='EPSG:4326', geometry=geometry)
address_gdf
# Out:
#                                           Name  \
# 0                          J.H.S. 185 - Queens
# 1                          I.S. 258 - Brooklyn
# 2                           I.S. 88 - Brooklyn
# 3                                Walton HS - X
# 4   P.S./I.S.30 Mary White Ovington - Brooklyn
# ..                                         ...
# 59                            I.S. 201 - Bronx
# 60                             P.S. 46 - Bronx
# 61                             Aviation HS - Q
# 62                            P.S. 102 - Bronx
# 63  Morris Heights Educational Complex - Bronx
#
#                                               Address   latitude  longitude  \
# 0                      147-26 25th Drive,NYC,NY,11354  40.774893 -73.818642
# 1                       141 Macon Street,NYC,NY,11216  40.681918 -73.945597
# 2                         544 7th Avenue,NYC,NY,11215  40.660181 -73.987931
# 3                  2780 Reservoir Avenue,NYC,NY,10468  40.870595 -73.897498
# 4                        7002 4th Avenue,NYC,NY,11209  40.633625 -74.024038
# ..                                                ...        ...        ...
# 59                     730 Bryant Avenue,NYC,NY,10474  40.816040 -73.885264
# 60                    2760 Briggs Avenue,NYC,NY,10458  40.867729 -73.890294
# 61                     45-30 36th Street,NYC,NY,11101  40.743475 -73.929464
# 62                    1827 Archer Street,NYC,NY,10460  40.838106 -73.865790
# 63  1780 Dr. Martin Luther King Jr. Blvd,NYC,NY,10453  40.802551 -73.933098
#
#                       geometry
# 0   POINT (-73.81864 40.77489)
# 1   POINT (-73.94560 40.68192)
# 2   POINT (-73.98793 40.66018)
# 3   POINT (-73.89750 40.87059)
# 4   POINT (-74.02404 40.63362)
# ..                         ...
# 59  POINT (-73.88526 40.81604)
# 60  POINT (-73.89029 40.86773)
# 61  POINT (-73.92946 40.74347)
# 62  POINT (-73.86579 40.83811)
# 63  POINT (-73.93310 40.80255)
#
# [63 rows x 5 columns]

# %%
m = leafmap.Map(width=800, height=500)
m.add_gdf(address_gdf, layer_name='Shelters', style={'color':'blue', 'weight':0.5})
m.zoom_to_gdf(address_gdf)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b1e7ef59c06d141161628584637b34c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b1e7ef59c06d141161628584637b34c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b1e7ef59c06d141161628584637b34c = L.map(
#                 &quot;map_6b1e7ef59c06d141161628584637b34c&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_6b1e7ef59c06d141161628584637b34c);
#
#
#
#
#
#             var tile_layer_d8431dd59c8eea3df270095a2bb54fdb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b1e7ef59c06d141161628584637b34c);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_6b1e7ef59c06d141161628584637b34c);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_6b1e7ef59c06d141161628584637b34c
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_74eff90ac13ceee82b99d8b5d198c43b = new L.Control.Draw(
#                 options
#             ).addTo( map_6b1e7ef59c06d141161628584637b34c );
#             map_6b1e7ef59c06d141161628584637b34c.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_6b1e7ef59c06d141161628584637b34c.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_51b9007a3c554cc8c2d9cf1aaf24b755 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_6b1e7ef59c06d141161628584637b34c.addControl(measure_control_51b9007a3c554cc8c2d9cf1aaf24b755);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_6b1e7ef59c06d141161628584637b34c.setView(e.geocode.center, 11);
#             }).addTo(map_6b1e7ef59c06d141161628584637b34c);
#
#
#
#             map_6b1e7ef59c06d141161628584637b34c.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#         funct

# %%
output_file = 'hurricane_evacuation_centers.shp'
output_path = os.path.join(output_folder, output_file)

address_gdf.to_file(filename=output_path)
