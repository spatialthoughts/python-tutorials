# %% [markdown]
# # Geocoding with Geopy and GeoPandas

# %% [markdown]
# Overview
#
# We will be working with an Excel sheet containing addresses of Hurricane Evacuation Centers in New York City. We will geocode these addresses and display the locations on a map.
#
# Input Layers:
#
# `Hurricane_Evacuation_Centers.xlsx`: A spreadsheet containing names and addresses of hurricane shelters inn NYC.
#
# Output:
# geocoded_results.shp: A shapefile with geocoded locations of the hurricane evacuation centers
#
# Data Credit: NYC Open Data Portal. [source](https://data.cityofnewyork.us/Public-Safety/Hurricane-Evacuation-Centers-Map-/ayer-cga7)

# %% [markdown]
# ## Setup and Data Download
#
# The following blocks of code will install the required packages and download the datasets to your Colab environment.

# %%
# %%capture
if 'google.colab' in str(get_ipython()):
    # !apt install libspatialindex-dev
    # !pip install fiona shapely pyproj rtree mapclassify
    # !pip install geopandas
    # !pip install openpyxl
    # !pip install leafmap

# %%
import os
import re
import pandas as pd
import geopandas as gpd
import leafmap.foliumap as leafmap
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
data_folder = 'data'
output_folder = 'output'

if not os.path.exists(data_folder):
    os.mkdir(data_folder)
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %%
def download(url):
    filename = os.path.join(data_folder, os.path.basename(url))
    if not os.path.exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)

download('https://github.com/spatialthoughts/python-tutorials/raw/main/data/' +
         'Hurricane_Evacuation_Centers.xlsx')
# Out:
# Downloaded data/Hurricane_Evacuation_Centers.xlsx

# %% [markdown]
# ## Procedure

# %% [markdown]
# Read the `Bars_and_pubs__with_patron_capacity.csv` file and convert it to a GeoDataFrame.

# %%
excel_file = 'Hurricane_Evacuation_Centers.xlsx'
excel_file_path = os.path.join(data_folder, excel_file)
address_df = pd.read_excel(excel_file_path, skiprows=[0])
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
# [64 rows x 7 columns]

# %% [markdown]
# The Nominatim geocoder expects the addresses with certain format. We fix our source addresses by making the street numbers as orfinal numbers
#
# Examples
#
# - `45-30 36 Street` → `45-30 36th Street`.
# - `544 7 Avenue` → `544 7th Avenue`

# %%
def make_ordinal(match):
    n = int(match.group(1))
    if 11 <= (n % 100) <= 13:
        suffix = 'th'
    else:
        suffix = ['th', 'st', 'nd', 'rd', 'th'][min(n % 10, 4)]
    return str(n) + suffix + match.group(2)

def update_address(row):
  old_address = row['ADDRESS']
  pattern = r'(\d+)(\s+(?:Street|Avenue|Blvd|Drive))'
  result = re.sub(pattern, make_ordinal, old_address)
  return result

address_df['ADDRESS_FIXED'] = address_df.apply(update_address, axis=1)
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE  \
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
#                            ADDRESS_FIXED
# 0                      147-26 25th Drive
# 1                       141 Macon Street
# 2                         544 7th Avenue
# 3                  2780 Reservoir Avenue
# 4                        7002 4th Avenue
# ..                                   ...
# 59                     730 Bryant Avenue
# 60                    2760 Briggs Avenue
# 61                     45-30 36th Street
# 62                    1827 Archer Street
# 63  1780 Dr. Martin Luther King Jr. Blvd
#
# [64 rows x 8 columns]

# %% [markdown]
# We also create a new column containing the full address.

# %%
address_df['Full_Address'] = (
    address_df['ADDRESS_FIXED'] + ',' +
    address_df['STATE']+ ',' +
    address_df['ZIP_CODE'].astype(str))
address_df
# Out:
#                 CITY                                     EC_Name  \
# 0           Flushing                         J.H.S. 185 - Queens
# 1           Brooklyn                         I.S. 258 - Brooklyn
# 2           Brooklyn                          I.S. 88 - Brooklyn
# 3              Bronx                               Walton HS - X
# 4           Brooklyn  P.S./I.S.30 Mary White Ovington - Brooklyn
# ..               ...                                         ...
# 59             Bronx                            I.S. 201 - Bronx
# 60             Bronx                             P.S. 46 - Bronx
# 61  Long Island City                             Aviation HS - Q
# 62             Bronx                            P.S. 102 - Bronx
# 63             Bronx  Morris Heights Educational Complex - Bronx
#
#                                  ADDRESS  ZIP_CODE  BOROCODE STATE ACCESSIBLE  \
# 0                        147-26 25 Drive     11354         4    NY          Y
# 1                       141 Macon Street     11216         3    NY          Y
# 2                           544 7 Avenue     11215         3    NY          Y
# 3                  2780 Reservoir Avenue     10468         2    NY          Y
# 4                          7002 4 Avenue     11209         3    NY          Y
# ..                                   ...       ...       ...   ...        ...
# 59                     730 Bryant Avenue     10474         2    NY          Y
# 60                    2760 Briggs Avenue     10458         2    NY          Y
# 61                       45-30 36 Street     11101         4    NY          Y
# 62                    1827 Archer Street     10460         2    NY          Y
# 63  1780 Dr. Martin Luther King Jr. Blvd     10453         2    NY          Y
#
#                            ADDRESS_FIXED  \
# 0                      147-26 25th Drive
# 1                       141 Macon Street
# 2                         544 7th Avenue
# 3                  2780 Reservoir Avenue
# 4                        7002 4th Avenue
# ..                                   ...
# 59                     730 Bryant Avenue
# 60                    2760 Briggs Avenue
# 61                     45-30 36th Street
# 62                    1827 Archer Street
# 63  1780 Dr. Martin Luther King Jr. Blvd
#
#                                      Full_Address
# 0                      147-26 25th Drive,NY,11354
# 1                       141 Macon Street,NY,11216
# 2                         544 7th Avenue,NY,11215
# 3                  2780 Reservoir Avenue,NY,10468
# 4                        7002 4th Avenue,NY,11209
# ..                                            ...
# 59                     730 Bryant Avenue,NY,10474
# 60                    2760 Briggs Avenue,NY,10458
# 61                     45-30 36th Street,NY,11101
# 62                    1827 Archer Street,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NY,10453
#
# [64 rows x 9 columns]

# %%
address_df = address_df[['EC_Name', 'Full_Address']]

# %%
from tqdm.notebook import tqdm

tqdm.pandas()

locator = Nominatim(user_agent='spatialthoughts', timeout=10)
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

address_df['location'] = address_df['Full_Address'].progress_apply(geocode)
address_df
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
#                                        EC_Name  \
# 0                          J.H.S. 185 - Queens
# 1                          I.S. 258 - Brooklyn
# 2                           I.S. 88 - Brooklyn
# 3                                Walton HS - X
# 4   P.S./I.S.30 Mary White Ovington - Brooklyn
# ..                                         ...
# 59                            I.S. 201 - Bronx
# 60                             P.S. 46 - Bronx
# 61                             Aviation HS - Q
# 62                            P.S. 102 - Bronx
# 63  Morris Heights Educational Complex - Bronx
#
#                                      Full_Address  \
# 0                      147-26 25th Drive,NY,11354
# 1                       141 Macon Street,NY,11216
# 2                         544 7th Avenue,NY,11215
# 3                  2780 Reservoir Avenue,NY,10468
# 4                        7002 4th Avenue,NY,11209
# ..                                            ...
# 59                     730 Bryant Avenue,NY,10474
# 60                    2760 Briggs Avenue,NY,10458
# 61                     45-30 36th Street,NY,11101
# 62                    1827 Archer Street,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NY,10453
#
#                                              location
# 0   (147-26, 25th Drive, Linden Hill, Queens, City...
# 1   (Junior High School 258, 141, Macon Street, Be...
# 2   (544, 7th Avenue, South Slope, Sunset Park, Ki...
# 3   (Celia Cruz High School of Music, 2780, Reserv...
# 4   (7002, 4th Avenue, Bay Ridge, Brooklyn, Kings ...
# ..                                                ...
# 59  (730, Bryant Avenue, Hunts Point, Bronx County...
# 60  (2760, Briggs Avenue, Bedford Park, Bronx Coun...
# 61  (45-30, 36th Street, Sunnyside, Queens, City o...
# 62  (Public School 102, 1827, Archer Street, Bronx...
# 63  (Dr Martin Luther King Jr Boulevard, Capitol H...
#
# [64 rows x 3 columns]

# %%
address_df['latitude'] = address_df['location'].apply(lambda loc: loc.latitude if loc else None)
address_df['longitude'] = address_df['location'].apply(lambda loc: loc.latitude if loc else None)
address_df
# Out:
#                                        EC_Name  \
# 0                          J.H.S. 185 - Queens
# 1                          I.S. 258 - Brooklyn
# 2                           I.S. 88 - Brooklyn
# 3                                Walton HS - X
# 4   P.S./I.S.30 Mary White Ovington - Brooklyn
# ..                                         ...
# 59                            I.S. 201 - Bronx
# 60                             P.S. 46 - Bronx
# 61                             Aviation HS - Q
# 62                            P.S. 102 - Bronx
# 63  Morris Heights Educational Complex - Bronx
#
#                                      Full_Address  \
# 0                      147-26 25th Drive,NY,11354
# 1                       141 Macon Street,NY,11216
# 2                         544 7th Avenue,NY,11215
# 3                  2780 Reservoir Avenue,NY,10468
# 4                        7002 4th Avenue,NY,11209
# ..                                            ...
# 59                     730 Bryant Avenue,NY,10474
# 60                    2760 Briggs Avenue,NY,10458
# 61                     45-30 36th Street,NY,11101
# 62                    1827 Archer Street,NY,10460
# 63  1780 Dr. Martin Luther King Jr. Blvd,NY,10453
#
#                                              location   latitude  longitude
# 0   (147-26, 25th Drive, Linden Hill, Queens, City...  40.774893  40.774893
# 1   (Junior High School 258, 141, Macon Street, Be...  40.681918  40.681918
# 2   (544, 7th Avenue, South Slope, Sunset Park, Ki...  40.660181  40.660181
# 3   (Celia Cruz High School of Music, 2780, Reserv...  40.870595  40.870595
# 4   (7002, 4th Avenue, Bay Ridge, Brooklyn, Kings ...  40.633625  40.633625
# ..                                                ...        ...        ...
# 59  (730, Bryant Avenue, Hunts Point, Bronx County...  40.816040  40.816040
# 60  (2760, Briggs Avenue, Bedford Park, Bronx Coun...  40.867729  40.867729
# 61  (45-30, 36th Street, Sunnyside, Queens, City o...  40.743475  40.743475
# 62  (Public School 102, 1827, Archer Street, Bronx...  40.838106  40.838106
# 63  (Dr Martin Luther King Jr Boulevard, Capitol H...  42.646082  42.646082
#
# [64 rows x 5 columns]

# %%
geometry = gpd.points_from_xy(address_df.longitude, address_df.latitude)
address_gdf = gpd.GeoDataFrame(address_df[['EC_Name', 'Full_Address']], crs='EPSG:4326', geometry=geometry)
address_gdf
# Out:
#                                        EC_Name  \
# 0                          J.H.S. 185 - Queens
# 1                          I.S. 258 - Brooklyn
# 2                           I.S. 88 - Brooklyn
# 3                                Walton HS - X
# 4   P.S./I.S.30 Mary White Ovington - Brooklyn
# ..                                         ...
# 59                            I.S. 201 - Bronx
# 60                             P.S. 46 - Bronx
# 61                             Aviation HS - Q
# 62                            P.S. 102 - Bronx
# 63  Morris Heights Educational Complex - Bronx
#
#                                      Full_Address                   geometry
# 0                      147-26 25th Drive,NY,11354  POINT (40.77489 40.77489)
# 1                       141 Macon Street,NY,11216  POINT (40.68192 40.68192)
# 2                         544 7th Avenue,NY,11215  POINT (40.66018 40.66018)
# 3                  2780 Reservoir Avenue,NY,10468  POINT (40.87059 40.87059)
# 4                        7002 4th Avenue,NY,11209  POINT (40.63362 40.63362)
# ..                                            ...                        ...
# 59                     730 Bryant Avenue,NY,10474  POINT (40.81604 40.81604)
# 60                    2760 Briggs Avenue,NY,10458  POINT (40.86773 40.86773)
# 61                     45-30 36th Street,NY,11101  POINT (40.74347 40.74347)
# 62                    1827 Archer Street,NY,10460  POINT (40.83811 40.83811)
# 63  1780 Dr. Martin Luther King Jr. Blvd,NY,10453  POINT (42.64608 42.64608)
#
# [64 rows x 3 columns]

# %%
address_gdf.explore()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/geopandas/explore.py in _explore(df, column, cmap, color, m, tiles, attr, tooltip, popup, highlight, categorical, legend, scheme, k, vmin, vmax, width, height, categories, classification_kwds, control_scale, marker_type, marker_kwds, style_kwds, highlight_kwds, missing_kwds, tooltip_kwds, popup_kwds, legend_kwds, map_kwds, **kwargs)
#     286         import matplotlib.pyplot as plt
# --> 287         from mapclassify import classify
#     288
#
# ModuleNotFoundError: No module named 'mapclassify'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-59-c85dd87ab01c> in <cell line: 1>()
# ----> 1 address_gdf.explore()
#
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py in explore(self, *args, **kwargs)
#    2099     @doc(_explore)
#    2100     def explore(self, *args, **kwargs):
# -> 2101         return _explore(self, *args, **kwargs)
#    2102
#    2103     def sjoin(self, df, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/geopandas/explore.py in _explore(df, column, cmap, color, m, tiles, attr, tooltip, popup, highlight, categorical, legend, scheme, k, vmin, vmax, width, height, categories, classification_kwds, control_scale, marker_type, marker_kwds, style_kwds, highlight_kwds, missing_kwds, tooltip_kwds, popup_kwds, legend_kwds, map_kwds, **kwargs)
#     295
#     296     except (ImportError, ModuleNotFoundError):
# --> 297         raise ImportError(
#     298             "The 'folium', 'matplotlib' and 'mapclassify' packages are required for "
#     299             "'explore()'. You can install them using "
#
# ImportError: The 'folium', 'matplotlib' and 'mapclassify' packages are required for 'explore()'. You can install them using 'conda install -c conda-forge folium matplotlib mapclassify' or 'pip install folium matplotlib mapclassify'.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
