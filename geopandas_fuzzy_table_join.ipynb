# %% [markdown]
# # Performing Fuzzy Table Joins

# %% [markdown]
# ## Overview
#
# This tutorial shows how to use GeoPandas to do a fuzzy table join. We will be covering advanced data cleaning techniques to be able to merge datasets from different sources.
#
# We will be working with 2 data layers for the Sri Lanka. Given the shapefile of Admin4 regions and a CSV file containing division-wise population statistics - we will learn how to merge them to display these indicators on a map.
#
# Input Layers:
# * `lka_admbnda_adm4_slsd_20220816.shp`: A shapefile of all Grama Niladhari (GN)Divisions (Admin Level 4) of Sri Lanka.
# * `GN_Division_Age_Group_of_Population.csv`: Age-wise population for all GN Divisions of Sri Lanka.
#
# Output:
# * `srilanka.gpkg`: A geopackage containing merged dataset.
#
# Data Credit:
# * Sri Lanka Population Statistics: Department of Census and Statistics - Sri Lanka.  Downloaded from DCS Map Portal](http://map.statistics.gov.lk/).
# * Sri Lanka - Subnational Administrative Boundaries: Sri Lanka administrative levels 0-4 shapefiles and gazetteer. Downloaded from [HDX portal](https://data.humdata.org/dataset/cod-ab-lka).

# %% [markdown]
# ## Setup and Data Download
#
# The following blocks of code will install the required packages and download the datasets to your Colab environment.

# %%
# %%capture
try:
    import geopandas
except ModuleNotFoundError:
    if 'google.colab' in str(get_ipython()):
        # !apt install libspatialindex-dev -qq
        # !pip install fiona shapely pyproj rtree --quiet
        # !pip install geopandas --quiet
        # !pip install thefuzz
    else:
        print('geopandas not found, please install via conda in your environment')

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from thefuzz import process

# %%
data_folder = 'data'
output_folder = 'output'

if not os.path.exists(data_folder):
    os.mkdir(data_folder)
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %%
def download(url):
    filename = os.path.join(data_folder, os.path.basename(url))
    if not os.path.exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)

data_url = 'https://storage.googleapis.com/spatialthoughts-public-data/srilanka/'

shapefile = 'lka_admbnda_adm4_slsd_20220816'
exts = ['.shp', '.shx', '.dbf', '.prj']
csv_file = 'GN_Division_Age_Group_of_Population.csv'

for ext in exts:
  download(data_url + shapefile + ext)

download(data_url + csv_file)

# %% [markdown]
# ## Procedure

# %% [markdown]
# ### Pre-Process Data Table
#
# The data table containing population couts is organized by 1 row per GN Division. We do not have a unique identifier that uniquely matches a GN Division. Since GN Division names are not unique amounf different provinces, we must create a unique identifier to be able to match it against another data source.

# %%
csv_path = os.path.join(data_folder, csv_file)
df = pd.read_csv(csv_path)
df
# Out:
#             GN Division   DS Division District      Province  \
# 0      Sammanthranapura       Colombo  Colombo       Western
# 1          Mattakkuliya       Colombo  Colombo       Western
# 2                Modara       Colombo  Colombo       Western
# 3           Madampitiya       Colombo  Colombo       Western
# 4             Mahawatta       Colombo  Colombo       Western
# ...                 ...           ...      ...           ...
# 13984            Demeda  Deraniyagala  Kegalle  Sabaragamuwa
# 13985      Kosgahakanda  Deraniyagala  Kegalle  Sabaragamuwa
# 13986          Yatiwala  Deraniyagala  Kegalle  Sabaragamuwa
# 13987            Magala  Deraniyagala  Kegalle  Sabaragamuwa
# 13988      Dikellakanda  Deraniyagala  Kegalle  Sabaragamuwa
#
#        Total Population  Less than 10  10 ~ 19  20 ~ 29  30 ~ 39  40 ~ 49  \
# 0                  7829          1604     1373     1262     1251      944
# 1                 28003          4932     4738     4379     4220     3702
# 2                 17757          3045     2791     3101     2688     2321
# 3                 12970          2834     2415     2066     1940     1687
# 4                  8809          1529     1495     1406     1357     1198
# ...                 ...           ...      ...      ...      ...      ...
# 13984               971           181      156      138      150      117
# 13985              2336           360      364      343      331      295
# 13986              1882           324      268      342      249      248
# 13987              1076           158      131      147      182      131
# 13988               684           114       93       86      121       97
#
#        50 ~ 59  60 ~ 69  70 ~ 79  80 ~ 89  90 and above
# 0          796      400      131       52            16
# 1         2920     1944      834      239            95
# 2         1872     1271      481      159            28
# 3         1147      581      238       52            10
# 4          953      555      213       75            28
# ...        ...      ...      ...      ...           ...
# 13984       93       90       35       10             1
# 13985      293      216      107       26             1
# 13986      210      154       67       17             3
# 13987      135      108       67       17             0
# 13988       75       64       27        6             1
#
# [13989 rows x 15 columns]

# %% [markdown]
# GN Division names are not unique, so they can't be used as identifiers for a join.

# %%
df[df['GN Division'].duplicated(keep=False)].sort_values('GN Division')
# Out:
#              GN Division    DS Division    District       Province  \
# 8944   Abakolawewa North      Ambanpola  Kurunegala  North Western
# 6521   Abakolawewa North    Weeraketiya  Hambantota       Southern
# 8954   Abakolawewa South      Ambanpola  Kurunegala  North Western
# 6520   Abakolawewa South    Weeraketiya  Hambantota       Southern
# 6303          Abhayapura  Lunugamvehera  Hambantota       Southern
# ...                  ...            ...         ...            ...
# 2375       Yatiyana East     Agalawatta    Kalutara        Western
# 978        Yatiyana East    Minuwangoda     Gampaha        Western
# 13634          Yodhagama      Aranayaka     Kegalle   Sabaragamuwa
# 13493          Yodhagama     Rambukkana     Kegalle   Sabaragamuwa
# 13371          Yodhagama   Embilipitiya   Ratnapura   Sabaragamuwa
#
#        Total Population  Less than 10  10 ~ 19  20 ~ 29  30 ~ 39  40 ~ 49  \
# 8944                561           100       81       81       83       83
# 6521                648           131      114       93       84       85
# 8954                488            72       77       67       62       70
# 6520                322            62       47       39       40       46
# 6303                624           123       87       98      120       46
# ...                 ...           ...      ...      ...      ...      ...
# 2375               1493           214      226      211      222      207
# 978                2004           324      335      269      317      299
# 13634               760           129      124       88       99      108
# 13493              1421           259      223      182      204      206
# 13371              5657           966      844      902      894      795
#
#        50 ~ 59  60 ~ 69  70 ~ 79  80 ~ 89  90 and above
# 8944        72       37       17        7             0
# 6521        65       37       25       11             3
# 8954        72       43       16        8             1
# 6520        41       29       11        6             1
# 6303        71       59       11        9             0
# ...        ...      ...      ...      ...           ...
# 2375       156      128       79       39            11
# 978        231      152       45       25             7
# 13634       99       67       35        9             2
# 13493      168      122       41       13             3
# 13371      701      381      125       40             9
#
# [2511 rows x 15 columns]

# %% [markdown]
# Let's create a unique idenfier by merging the Admin4, Admin3, Admin2 and Admin1 names. We also remove  whitespaces and convert the names to lowercase to ensure the match is case insensitive.

# %%
df_processed = df.copy()
gn_division = df_processed['GN Division'].str.lower().str.replace(' ', '')
ds_division = df_processed['DS Division'].str.lower().str.replace(' ', '')
district = df_processed['District'].str.lower().str.replace(' ', '')
province = df_processed['Province'].str.lower().str.replace(' ', '')

df_processed['joinkey'] = gn_division + ds_division + district + province
df_processed
# Out:
#             GN Division   DS Division District      Province  \
# 0      Sammanthranapura       Colombo  Colombo       Western
# 1          Mattakkuliya       Colombo  Colombo       Western
# 2                Modara       Colombo  Colombo       Western
# 3           Madampitiya       Colombo  Colombo       Western
# 4             Mahawatta       Colombo  Colombo       Western
# ...                 ...           ...      ...           ...
# 13984            Demeda  Deraniyagala  Kegalle  Sabaragamuwa
# 13985      Kosgahakanda  Deraniyagala  Kegalle  Sabaragamuwa
# 13986          Yatiwala  Deraniyagala  Kegalle  Sabaragamuwa
# 13987            Magala  Deraniyagala  Kegalle  Sabaragamuwa
# 13988      Dikellakanda  Deraniyagala  Kegalle  Sabaragamuwa
#
#        Total Population  Less than 10  10 ~ 19  20 ~ 29  30 ~ 39  40 ~ 49  \
# 0                  7829          1604     1373     1262     1251      944
# 1                 28003          4932     4738     4379     4220     3702
# 2                 17757          3045     2791     3101     2688     2321
# 3                 12970          2834     2415     2066     1940     1687
# 4                  8809          1529     1495     1406     1357     1198
# ...                 ...           ...      ...      ...      ...      ...
# 13984               971           181      156      138      150      117
# 13985              2336           360      364      343      331      295
# 13986              1882           324      268      342      249      248
# 13987              1076           158      131      147      182      131
# 13988               684           114       93       86      121       97
#
#        50 ~ 59  60 ~ 69  70 ~ 79  80 ~ 89  90 and above  \
# 0          796      400      131       52            16
# 1         2920     1944      834      239            95
# 2         1872     1271      481      159            28
# 3         1147      581      238       52            10
# 4          953      555      213       75            28
# ...        ...      ...      ...      ...           ...
# 13984       93       90       35       10             1
# 13985      293      216      107       26             1
# 13986      210      154       67       17             3
# 13987      135      108       67       17             0
# 13988       75       64       27        6             1
#
#                                            joinkey
# 0            sammanthranapuracolombocolombowestern
# 1                mattakkuliyacolombocolombowestern
# 2                      modaracolombocolombowestern
# 3                 madampitiyacolombocolombowestern
# 4                   mahawattacolombocolombowestern
# ...                                            ...
# 13984        demedaderaniyagalakegallesabaragamuwa
# 13985  kosgahakandaderaniyagalakegallesabaragamuwa
# 13986      yatiwaladeraniyagalakegallesabaragamuwa
# 13987        magaladeraniyagalakegallesabaragamuwa
# 13988  dikellakandaderaniyagalakegallesabaragamuwa
#
# [13989 rows x 16 columns]

# %% [markdown]
# We still have some duplicates.

# %%
duplicate_df = df_processed[df_processed.duplicated('joinkey', keep=False)].sort_values('joinkey')
duplicate_df
# Out:
#                             GN Division       DS Division      District  \
# 10341                      Ahugoda West       Polgahawela    Kurunegala
# 10335                      Ahugoda West       Polgahawela    Kurunegala
# 10694                        Aluthwatta            Chilaw      Puttalam
# 10693                        Aluthwatta            Chilaw      Puttalam
# 2781                   Dewahandiya East        Udadumbara         Kandy
# 2793                   Dewahandiya East        Udadumbara         Kandy
# 2481                        Gorakadoowa       Walallavita      Kalutara
# 2487                        Gorakadoowa       Walallavita      Kalutara
# 699                               Halpe      Divulapitiya       Gampaha
# 757                               Halpe      Divulapitiya       Gampaha
# 4530                        High Forest          Walapane  Nuwara Eliya
# 4527                        High Forest          Walapane  Nuwara Eliya
# 11237                    Hurulunikawewa  Galenbindunuwewa  Anuradhapura
# 11243                    Hurulunikawewa  Galenbindunuwewa  Anuradhapura
# 8771                        Jinna Nagar            Muttur   Trincomalee
# 8777                        Jinna Nagar            Muttur   Trincomalee
# 9074                            Konwewa              Maho    Kurunegala
# 9112                            Konwewa              Maho    Kurunegala
# 9114                         Kumbukwewa              Maho    Kurunegala
# 9106                         Kumbukwewa              Maho    Kurunegala
# 9111                         Kumbukwewa              Maho    Kurunegala
# 2455                         Miriswatta       Walallavita      Kalutara
# 2488                         Miriswatta       Walallavita      Kalutara
# 8305   Periyaneelavanai  Muslim Section          Kalmunai        Ampara
# 8306   Periyaneelavanai  Muslim Section          Kalmunai        Ampara
# 2109                  Pothupitiya North          Kalutara      Kalutara
# 2125                  Pothupitiya North          Kalutara      Kalutara
# 1389                      Sapugasthenna       Attanagalla       Gampaha
# 1334                      Sapugasthenna       Attanagalla       Gampaha
# 10559                          Udappuwa            Mundel      Puttalam
# 10560                          Udappuwa            Mundel      Puttalam
#
#             Province  Total Population  Less than 10  10 ~ 19  20 ~ 29  \
# 10341  North Western               533            82       82       55
# 10335  North Western               876           153      134      115
# 10694  North Western              1350           179      238      188
# 10693  North Western              1582           247      250      222
# 2781         Central               224            38       34       33
# 2793         Central               378            58       65       50
# 2481         Western               938           147      139      128
# 2487         Western              1624           288      279      244
# 699          Western              2219           356      361      336
# 757          Western              2559           450      373      335
# 4530         Central              1511           311      241      203
# 4527         Central              2688           607      411      345
# 11237  North Central              1281           252      168      164
# 11243  North Central              1148           229      184      124
# 8771         Eastern              1008           267      218      167
# 8777         Eastern              1275           322      285      185
# 9074   North Western               667           116      103       94
# 9112   North Western               704           128      109       90
# 9114   North Western               764           132      121       91
# 9106   North Western               715           107       98      108
# 9111   North Western               670           115       99       76
# 2455         Western              1150           201      189      172
# 2488         Western               779           121      111      106
# 8305         Eastern              2014           469      406      218
# 8306         Eastern               930           247      164      128
# 2109         Western              1296           188      158      200
# 2125         Western              2376           379      362      369
# 1389         Western              1028           164      158      149
# 1334         Western              2199           374      388      243
# 10559  North Western              1087           137      175      189
# 10560  North Western              3011           476      532      570
#
#        30 ~ 39  40 ~ 49  50 ~ 59  60 ~ 69  70 ~ 79  80 ~ 89  90 and above  \
# 10341       78       90       64       48       23        8             3
# 10335      140      111       97       79       33       14             0
# 10694      186      187      162      139       54       17             0
# 10693      274      188      187      145       57       12             0
# 2781        29       40       28       12        7        3             0
# 2793        48       49       57       32       12        6             1
# 2481       131      121       99       95       59       14             5
# 2487       252      195      186      107       43       23             7
# 699        356      317      227      169       66       25             6
# 757        455      330      302      179       98       30             7
# 4530       230      208      163      107       31       12             5
# 4527       418      345      266      212       67       14             3
# 11237      202      155      166      127       29       12             6
# 11243      196      128      123      110       41        9             4
# 8771       112       95       95       48        6        0             0
# 8777       163      135      111       58       10        5             1
# 9074        92       98       97       35       22       10             0
# 9112       111       85       93       52       25        9             2
# 9114       140      103       98       45       28        3             3
# 9106       100      105      107       50       30        8             2
# 9111       106      105       69       50       34       14             2
# 2455       157      132      136       99       45       14             5
# 2488       128      104       62       74       52       19             2
# 8305       287      317      176       91       37       10             3
# 8306       139      131       78       25       16        2             0
# 2109       190      182      177      128       47       22             4
# 2125       361      310      292      190       80       30             3
# 1389       165      133      125       91       29       12             2
# 1334       341      411      225      127       58       28             4
# 10559      147      162      132       98       37        8             2
# 10560      433      392      334      190       65       17             2
#
#                                                  joinkey
# 10341       ahugodawestpolgahawelakurunegalanorthwestern
# 10335       ahugodawestpolgahawelakurunegalanorthwestern
# 10694               aluthwattachilawputtalamnorthwestern
# 10693               aluthwattachilawputtalamnorthwestern
# 2781               dewahandiyaeastudadumbarakandycentral
# 2793               dewahandiyaeastudadumbarakandycentral
# 2481               gorakadoowawalallavitakalutarawestern
# 2487               gorakadoowawalallavitakalutarawestern
# 699                      halpedivulapitiyagampahawestern
# 757                      halpedivulapitiyagampahawestern
# 4530                highforestwalapanenuwaraeliyacentral
# 4527                highforestwalapanenuwaraeliyacentral
# 11237  hurulunikawewagalenbindunuwewaanuradhapuranort...
# 11243  hurulunikawewagalenbindunuwewaanuradhapuranort...
# 8771                  jinnanagarmutturtrincomaleeeastern
# 8777                  jinnanagarmutturtrincomaleeeastern
# 9074                   konwewamahokurunegalanorthwestern
# 9112                   konwewamahokurunegalanorthwestern
# 9114                kumbukwewamahokurunegalanorthwestern
# 9106                kumbukwewamahokurunegalanorthwestern
# 9111                kumbukwewamahokurunegalanorthwestern
# 2455                miriswattawalallavitakalutarawestern
# 2488                miriswattawalallavitakalutarawestern
# 8305   periyaneelavanaimuslimsectionkalmunaiamparaeas...
# 8306   periyaneelavanaimuslimsectionkalmunaiamparaeas...
# 2109             pothupitiyanorthkalutarakalutarawestern
# 2125             pothupitiyanorthkalutarakalutarawestern
# 1389              sapugasthennaattanagallagampahawestern
# 1334              sapugasthennaattanagallagampahawestern
# 10559                 udappuwamundelputtalamnorthwestern
# 10560                 udappuwamundelputtalamnorthwestern

# %% [markdown]
# Since these refer to the same region, we merge the data for duplicate admin4 regions. While merging the rows, we sum the population counts from each row having the same key.

# %%
df_processed.columns
# Out:
# Index(['GN Division', 'DS Division', 'District', 'Province',
#        'Total Population', 'Less than 10', '10 ~ 19', '20 ~ 29', '30 ~ 39',
#        '40 ~ 49', '50 ~ 59', '60 ~ 69', '70 ~ 79', '80 ~ 89', '90 and above',
#        'joinkey'],
#       dtype='object')

# %%
df_dissolved = df_processed.groupby(['joinkey'],as_index=False).agg({
    'GN Division': 'first',
    'DS Division': 'first',
    'District': 'first',
    'Province': 'first',
    'Total Population': sum,
    'Less than 10': sum,
    '10 ~ 19': sum,
    '20 ~ 29': sum,
    '30 ~ 39': sum,
    '40 ~ 49': sum,
    '50 ~ 59': sum,
    '60 ~ 69': sum,
    '70 ~ 79': sum,
    '80 ~ 89': sum,
    '90 and above': sum
})
df_dissolved = df_dissolved[['joinkey', 'Total Population', 'Less than 10',
                             '10 ~ 19', '20 ~ 29', '30 ~ 39','40 ~ 49',
                             '50 ~ 59', '60 ~ 69', '70 ~ 79', '80 ~ 89',
                             '90 and above']]

# %%
print('Total Records of original table', len(df))
print('Total Records of processed table', len(df_dissolved))
# Out:
# Total Records of original table 13989
# Total Records of processed table 13973

# %% [markdown]
# ### Pre-Process Shapefile
#
# Our shapefile comes from a different source and thus has a different structure. We need to match each feature with a record from the data table. We process the data to create a similar 'joinkey' and remove duplicates.

# %%
shapefile_path = os.path.join(data_folder, shapefile + '.shp')
gdf = gpd.read_file(shapefile_path, encoding='utf-8')
gdf
# Out:
#        Shape_Leng  Shape_Area           ADM4_EN         ADM4_SI ADM4_TA  \
# 0        0.019689    0.000015  Sammanthranapura  සම්මන්ත්‍රණපුර    None
# 1        0.072878    0.000177      Mattakkuliya     මට්ටක්කුලිය    None
# 2        0.052290    0.000064            Modara            මෝදර    None
# 3        0.019201    0.000023       Madampitiya      මාදම්පිටිය    None
# 4        0.033889    0.000042         Mahawatta          මහවත්ත    None
# ...           ...         ...               ...             ...     ...
# 14038    0.149196    0.000260            Demeda           දෙමැද    None
# 14039    0.143733    0.000765      Kosgahakanda      කොස්ගහකන්ද    None
# 14040    0.122895    0.000583          Yatiwala           යටිවල    None
# 14041    0.246448    0.001756            Magala            මාගල    None
# 14042    0.275330    0.002457      Dikellakanda    දික්ඇල්ලකන්ද    None
#
#       ADM4_PCODE ADM4_REF       ADM3_EN   ADM3_SI     ADM3_TA  ...  \
# 0      LK1103005     None       Colombo      කොළඹ    கொழும்பு  ...
# 1      LK1103010     None       Colombo      කොළඹ    கொழும்பு  ...
# 2      LK1103015     None       Colombo      කොළඹ    கொழும்பு  ...
# 3      LK1103020     None       Colombo      කොළඹ    கொழும்பு  ...
# 4      LK1103025     None       Colombo      කොළඹ    கொழும்பு  ...
# ...          ...      ...           ...       ...         ...  ...
# 14038  LK9233110     None  Deraniyagala  දැරණියගල  தெரனியாகலை  ...
# 14039  LK9233115     None  Deraniyagala  දැරණියගල  தெரனியாகலை  ...
# 14040  LK9233120     None  Deraniyagala  දැරණියගල  தெரனியாகலை  ...
# 14041  LK9233125     None  Deraniyagala  දැරණියගල  தெரனியாகலை  ...
# 14042  LK9233130     None  Deraniyagala  දැරණියගල  தெரனியாகலை  ...
#
#                ADM1_TA ADM1_PCODE    ADM0_EN     ADM0_SI ADM0_TA ADM0_PCODE  \
# 0        மேல் மாகாணம்         LK1  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# 1        மேல் மாகாணம்         LK1  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# 2        மேல் மாகாணம்         LK1  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# 3        மேல் மாகாணம்         LK1  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# 4        மேல் மாகாணம்         LK1  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# ...                ...        ...        ...         ...     ...        ...
# 14038  சபரகமுவ மாகாணம்        LK9  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# 14039  சபரகமுவ மாகாணம்        LK9  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# 14040  சபரகமுவ மாகாணம்        LK9  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# 14041  சபரகமுவ மாகாணம்        LK9  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
# 14042  சபரகமுவ மாகாணம்        LK9  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK
#
#              date     validOn validTo  \
# 0      2022-08-02  2022-08-16    None
# 1      2022-08-02  2022-08-16    None
# 2      2022-08-02  2022-08-16    None
# 3      2022-08-02  2022-08-16    None
# 4      2022-08-02  2022-08-16    None
# ...           ...         ...     ...
# 14038  2022-08-02  2022-08-16    None
# 14039  2022-08-02  2022-08-16    None
# 14040  2022-08-02  2022-08-16    None
# 14041  2022-08-02  2022-08-16    None
# 14042  2022-08-02  2022-08-16    None
#
#                                                 geometry
# 0      POLYGON ((79.88040 6.98093, 79.88032 6.98062, ...
# 1      POLYGON ((79.88217 6.97996, 79.88218 6.97995, ...
# 2      POLYGON ((79.87507 6.96483, 79.87504 6.96479, ...
# 3      POLYGON ((79.87852 6.96328, 79.87849 6.96314, ...
# 4      POLYGON ((79.87252 6.96160, 79.87261 6.96151, ...
# ...                                                  ...
# 14038  POLYGON ((80.35891 6.87436, 80.35961 6.87238, ...
# 14039  POLYGON ((80.37824 6.89164, 80.37861 6.89139, ...
# 14040  POLYGON ((80.40891 6.87830, 80.40845 6.87784, ...
# 14041  POLYGON ((80.41601 6.88094, 80.41600 6.88093, ...
# 14042  POLYGON ((80.50004 6.86371, 80.50005 6.86340, ...
#
# [14043 rows x 27 columns]

# %%
gdf_processed = gdf.copy()
gdf_processed = gdf_processed.rename(columns = {
    'ADM4_EN': 'GN Division',
    'ADM3_EN': 'DS Division',
    'ADM2_EN': 'District',
    'ADM1_EN': 'Province'})

gn_division = gdf_processed['GN Division'].str.lower().str.replace(' ', '')
ds_division = gdf_processed['DS Division'].str.lower().str.replace(' ', '')
district = gdf_processed['District'].str.lower().str.replace(' ', '')
province = gdf_processed['Province'].str.lower().str.replace(' ', '')

gdf_processed['joinkey'] = gn_division + ds_division + district + province
gdf_processed = gdf_processed[['GN Division', 'DS Division', 'District', 'Province', 'joinkey', 'geometry']]
gdf_processed
# Out:
#             GN Division   DS Division District      Province  \
# 0      Sammanthranapura       Colombo  Colombo       Western
# 1          Mattakkuliya       Colombo  Colombo       Western
# 2                Modara       Colombo  Colombo       Western
# 3           Madampitiya       Colombo  Colombo       Western
# 4             Mahawatta       Colombo  Colombo       Western
# ...                 ...           ...      ...           ...
# 14038            Demeda  Deraniyagala  Kegalle  Sabaragamuwa
# 14039      Kosgahakanda  Deraniyagala  Kegalle  Sabaragamuwa
# 14040          Yatiwala  Deraniyagala  Kegalle  Sabaragamuwa
# 14041            Magala  Deraniyagala  Kegalle  Sabaragamuwa
# 14042      Dikellakanda  Deraniyagala  Kegalle  Sabaragamuwa
#
#                                            joinkey  \
# 0            sammanthranapuracolombocolombowestern
# 1                mattakkuliyacolombocolombowestern
# 2                      modaracolombocolombowestern
# 3                 madampitiyacolombocolombowestern
# 4                   mahawattacolombocolombowestern
# ...                                            ...
# 14038        demedaderaniyagalakegallesabaragamuwa
# 14039  kosgahakandaderaniyagalakegallesabaragamuwa
# 14040      yatiwaladeraniyagalakegallesabaragamuwa
# 14041        magaladeraniyagalakegallesabaragamuwa
# 14042  dikellakandaderaniyagalakegallesabaragamuwa
#
#                                                 geometry
# 0      POLYGON ((79.88040 6.98093, 79.88032 6.98062, ...
# 1      POLYGON ((79.88217 6.97996, 79.88218 6.97995, ...
# 2      POLYGON ((79.87507 6.96483, 79.87504 6.96479, ...
# 3      POLYGON ((79.87852 6.96328, 79.87849 6.96314, ...
# 4      POLYGON ((79.87252 6.96160, 79.87261 6.96151, ...
# ...                                                  ...
# 14038  POLYGON ((80.35891 6.87436, 80.35961 6.87238, ...
# 14039  POLYGON ((80.37824 6.89164, 80.37861 6.89139, ...
# 14040  POLYGON ((80.40891 6.87830, 80.40845 6.87784, ...
# 14041  POLYGON ((80.41601 6.88094, 80.41600 6.88093, ...
# 14042  POLYGON ((80.50004 6.86371, 80.50005 6.86340, ...
#
# [14043 rows x 6 columns]

# %% [markdown]
# There are some duplicate polygons having the same 'joinkey'.

# %%
duplicate_gdf = gdf_processed[gdf_processed.duplicated('joinkey', keep=False)].sort_values('joinkey')
duplicate_gdf
# Out:
#          GN Division   DS Division    District       Province  \
# 7879       [unknown]  Eravur Pattu  Batticaloa        Eastern
# 7877       [unknown]  Eravur Pattu  Batticaloa        Eastern
# 7876       [unknown]  Eravur Pattu  Batticaloa        Eastern
# 7875       [unknown]  Eravur Pattu  Batticaloa        Eastern
# 7838       [unknown]  Eravur Pattu  Batticaloa        Eastern
# ...              ...           ...         ...            ...
# 2455      Miriswatta   Walallawita    Kalutara        Western
# 1389   Sapugasthenna   Attanagalla     Gampaha        Western
# 1334   Sapugasthenna   Attanagalla     Gampaha        Western
# 10612       Udappuwa        Mundel    Puttalam  North Western
# 10613       Udappuwa        Mundel    Puttalam  North Western
#
#                                       joinkey  \
# 7879    [unknown]eravurpattubatticaloaeastern
# 7877    [unknown]eravurpattubatticaloaeastern
# 7876    [unknown]eravurpattubatticaloaeastern
# 7875    [unknown]eravurpattubatticaloaeastern
# 7838    [unknown]eravurpattubatticaloaeastern
# ...                                       ...
# 2455     miriswattawalallawitakalutarawestern
# 1389   sapugasthennaattanagallagampahawestern
# 1334   sapugasthennaattanagallagampahawestern
# 10612      udappuwamundelputtalamnorthwestern
# 10613      udappuwamundelputtalamnorthwestern
#
#                                                 geometry
# 7879   POLYGON ((81.59942 7.77887, 81.59955 7.77876, ...
# 7877   POLYGON ((81.62471 7.78231, 81.62462 7.78238, ...
# 7876   POLYGON ((81.60296 7.78297, 81.60295 7.78290, ...
# 7875   POLYGON ((81.60157 7.78693, 81.60159 7.78693, ...
# 7838   POLYGON ((81.60935 7.79416, 81.60937 7.79408, ...
# ...                                                  ...
# 2455   POLYGON ((80.09314 6.43583, 80.09315 6.43582, ...
# 1389   POLYGON ((80.17102 7.10247, 80.17166 7.10118, ...
# 1334   POLYGON ((80.04911 7.12307, 80.04923 7.12303, ...
# 10612  POLYGON ((79.79870 7.74958, 79.79863 7.74951, ...
# 10613  POLYGON ((79.80068 7.74515, 79.80076 7.74417, ...
#
# [73 rows x 6 columns]

# %%
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(10,10)

# Plot all features and highlight duplicates
gdf_processed.plot(ax=ax, facecolor='none', edgecolor='#bdbdbd', linewidth=0.2)
duplicate_gdf.plot('joinkey', ax=ax, categorical=True, edgecolor='#ffffff', linewidth=0.5)

# Zoom to a specific region
selected = gdf_processed[gdf_processed['DS Division'] == 'Mundel']
minx, miny, maxx, maxy = selected.total_bounds
ax.set_xlim(minx, maxx)
ax.set_ylim(miny, maxy)

ax.set_axis_off()
ax.set_title('Duplicate Polygons', size = 18)

plt.show()

# %% [markdown]
# We dissolve (merge) these polygon boundaries to create a single region from multiple polygons having the same attributes.

# %%
gdf_dissolved = gdf_processed.dissolve(by='joinkey', aggfunc={
    'GN Division': 'first',
    'DS Division': 'first',
    'District': 'first',
    'Province': 'first'})
gdf_dissolved = gdf_dissolved.reset_index()

# %%
print('Total Records of original shapefile', len(gdf))
print('Total Records of processed shapefile', len(gdf_dissolved))
# Out:
# Total Records of original shapefile 14043
# Total Records of processed shapefile 13987

# %% [markdown]
# ### Table Join
#
# Finally, we do a table join using GeoPandas merge().

# %% [markdown]
# We have almost equal count of features between the shapefile and table now. There are still a few polygons that do not have corresponding population counts. They will be removed from the output layer.

# %%
print('Total Records of processed shapefile', len(gdf_dissolved))
print('Total Records of processed table', len(df_dissolved))
# Out:
# Total Records of processed shapefile 13987
# Total Records of processed table 13973

# %%
merged = gdf_dissolved.merge(df_dissolved, on='joinkey')

# %%
print('Total Records of merged shapefile', len(merged))
# Out:
# Total Records of merged shapefile 10747

# %% [markdown]
# There are still many records that do not have an exact match between the shapefile and the population table. This is due to small differences in their spellings. We can instead try a fuzzy match.

# %% [markdown]
# ### Fuzzy Join

# %% [markdown]
# We use the fuzzy matching package [TheFuzz](https://github.com/seatgeek/thefuzz) (formerly FuzzyWuzzy) to find the closest match to each record.
#
# Fuzzy matching for large tables can take long time, so we use `tqdm` package to track the progress.

# %%
gdf_dissolved.rename(columns = {'joinkey':'joinkey_exact'}, inplace=True)

# %%
from tqdm import tqdm

def getFuzzyMatch(row):
    joinkey = row['joinkey_exact']
    results = process.extractOne(joinkey, df_dissolved.joinkey)
    match = results[0]
    score = results[1]
    return match, score

tqdm.pandas()
gdf_dissolved[['match', 'score']] = gdf_dissolved.progress_apply(
    getFuzzyMatch, axis=1, result_type='expand')
# Out:
# 100%|███████████████████████████████████| 13987/13987 [7:37:11<00:00,  1.96s/it]

# %% [markdown]
# The matches with scores less than 100 are fuzzy matches.

# %%
gdf_dissolved[gdf_dissolved['score'] != 100][['joinkey_exact', 'match', 'score']].sort_values('score', ascending=False)
# Out:
#                                            joinkey_exact  \
# 0         041/2kanuwarajanganayaanuradhapuranorthcentral
# 10708  puthukudiyiruppuwestputhukkudiyiruppumullaitiv...
# 3936      hingurakgodahigurakgodapolonnaruwanorthcentral
# 3933         hingurakahigurakgodapolonnaruwanorthcentral
# 3932   hingurakabandaragamahigurakgodapolonnaruwanort...
# ...                                                  ...
# 5527           kawattikudatown&gravetstrincomaleeeastern
# 8                       [unknown]ambangangamatalecentral
# 14                        [unknown]kalmunaiamparaeastern
# 4473                   injusternorwoodnuwaraeliyacentral
# 8969              newvalleygamanorwoodnuwaraeliyacentral
#
#                                                    match  score
# 0          41/2kanuwarajanganayaanuradhapuranorthcentral     99
# 10708  puthukkudiyiruppuwestputhukkudiyiruppumullaiti...     99
# 3936     hingurakgodahingurakgodapolonnaruwanorthcentral     99
# 3933        hingurakahingurakgodapolonnaruwanorthcentral     99
# 3932   hingurakabandaragamahingurakgodapolonnaruwanor...     99
# ...                                                  ...    ...
# 5527   kanniyatrincomaleetownandgravetstrincomaleeeas...     77
# 8                               ambananaulamatalecentral     76
# 14                   kalmunaikudi01kalmunaiamparaeastern     75
# 4473                injustryambagamuwanuwaraeliyacentral     75
# 8969                 manelwalawalapanenuwaraeliyacentral     74
#
# [3236 rows x 3 columns]

# %% [markdown]
# We can use all matches with a score of above a threshold. You need to use your discretion and local knowledge to determine the appropriate threshold. Here we see all matches with a low score.

# %%
score_threshold = 90
gdf_dissolved[gdf_dissolved['score'] < score_threshold].sort_values('score')
# Out:
#                                            joinkey_exact  \
# 8969              newvalleygamanorwoodnuwaraeliyacentral
# 4473                   injusternorwoodnuwaraeliyacentral
# 14                        [unknown]kalmunaiamparaeastern
# 8                       [unknown]ambangangamatalecentral
# 695          arayampathy_1manmunaipattubatticaloaeastern
# ...                                                  ...
# 13575         welipathayayakalthotaratnapurasabaragamuwa
# 20     [unknown]manmunaisouth&eruvilpattubatticaloaea...
# 5853      kirimichchaikoralaipattunorthbatticaloaeastern
# 5131     kankeyanodaisouthmanmunaipattubatticaloaeastern
# 8715                     narangamuwalaggalamatalecentral
#
#                                                 geometry         GN Division  \
# 8969   POLYGON ((80.61848 6.85457, 80.61893 6.85417, ...       Newvalleygama
# 4473   POLYGON ((80.63870 6.85560, 80.63902 6.85526, ...            Injuster
# 14     MULTIPOLYGON (((81.81247 7.39900, 81.81038 7.4...           [unknown]
# 8      POLYGON ((80.65829 7.56101, 80.65825 7.56086, ...           [unknown]
# 695    POLYGON ((81.72984 7.67188, 81.72988 7.67180, ...       Arayampathy_1
# ...                                                  ...                 ...
# 13575  POLYGON ((80.88161 6.62168, 80.88163 6.62163, ...       Welipathayaya
# 20     MULTIPOLYGON (((81.80616 7.44008, 81.80620 7.4...           [unknown]
# 5853   POLYGON ((81.48639 8.01400, 81.48636 8.01399, ...        Kirimichchai
# 5131   POLYGON ((81.73003 7.66296, 81.73003 7.66296, ...  Kankeyanodai South
# 8715   POLYGON ((80.83942 7.49877, 80.83943 7.49873, ...         Narangamuwa
#
#                          DS Division      District      Province  \
# 8969                         Norwood  Nuwara Eliya       Central
# 4473                         Norwood  Nuwara Eliya       Central
# 14                          Kalmunai        Ampara       Eastern
# 8                         Ambanganga        Matale       Central
# 695                   Manmunai Pattu    Batticaloa       Eastern
# ...                              ...           ...           ...
# 13575                       Kalthota     Ratnapura  Sabaragamuwa
# 20     Manmunai South & Eruvil Pattu    Batticaloa       Eastern
# 5853             Koralai Pattu North    Batticaloa       Eastern
# 5131                  Manmunai Pattu    Batticaloa       Eastern
# 8715                         Laggala        Matale       Central
#
#                                                    match  score
# 8969                 manelwalawalapanenuwaraeliyacentral     74
# 4473                injustryambagamuwanuwaraeliyacentral     75
# 14                   kalmunaikudi01kalmunaiamparaeastern     75
# 8                               ambananaulamatalecentral     76
# 695    araipattai1manmunaipattu(araipattai)batticaloa...     77
# ...                                                  ...    ...
# 13575        welipathayayabalangodaratnapurasabaragamuwa     89
# 20     mankadumanmunaisouth&eruvilpattubatticaloaeastern     89
# 5853   kirimichaikoralaipattunorth(vaharai)batticaloa...     89
# 5131   kankeyanodaisouthmanmunaipattu(araipattai)batt...     89
# 8715                      narangamuwamatalematalecentral     89
#
# [550 rows x 8 columns]

# %% [markdown]
# Save the high score matches as `joinkey`.

# %%
gdf_dissolved['joinkey'] = np.where(
    gdf_dissolved['score'] >= 90, 
    gdf_dissolved['match'],
    '')

# %% [markdown]
# Use the new `joinkey` which contains the fuzzy matches from the `df_dissolved` table. Now we will get a lot more matches of records.

# %%
merged = gdf_dissolved.merge(df_dissolved, on='joinkey')

# %%
print('Total Records of merged shapefile', len(merged))
# Out:
# Total Records of merged shapefile 13437

# %% [markdown]
# ### Save the datasets

# %%
output_dir = 'output'
output_filename = 'srilanka.gpkg'
output_path = os.path.join(output_dir, output_filename)

gdf_dissolved.to_file(driver='GPKG', filename=output_path, layer='admin4polygons', encoding='utf-8')
merged.to_file(driver='GPKG', filename=output_path, layer='merged', encoding='utf-8')

print('Successfully written output file at {}'.format(output_path))
# Out:
# Successfully written output file at output/srilanka.gpkg
